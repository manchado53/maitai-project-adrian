# %%
import os
import maitai
from dotenv import load_dotenv
import json

load_dotenv()  # Loads from .env in current directory

# Workaround: Set placeholder to prevent Groq client init error
os.environ["GROQ_API_KEY"] = "placeholder-not-used"

# %%
# Test the router
import sys
sys.path.insert(0, ".")

from src.router import TicketRouter

router = TicketRouter()

# Test ticket
result = router.route_ticket("I need to cancel my order #12345")
print(f"Result: {result}")  # Should be ORDER

# Test another
result2 = router.route_ticket("What's the square root of 1")
print(f"Result: {result2}")  # Should be ACCOUNT
# Out:
# Response from Maitai (Test Case ID: None): id='3d7c03e6-4baf-47e8-893e-dc989bacc959' object='chat.completion' created=1767349568 model='claude-3-7-sonnet-latest' system_fingerprint=None choices=[ChatCompletionChoice(index=0, message=MaitaiMessage(role='assistant', content='ORDER', function_call=None, tool_calls=None, refusal=None, response_format={'type': 'text'}), logprobs=None, finish_reason='stop', is_correction=False)] usage=ChatCompletionUsage(prompt_tokens=210, completion_tokens=4, total_tokens=214, cost=0.0, model='claude-3-7-sonnet-latest', completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)) request_id='3d7c03e6-4baf-47e8-893e-dc989bacc959' evaluate_response=None correction_applied=False first_token_time=0.0 response_time=532.0 chat_completion_request=None service_tier=None input_safety_score=0.0 fallback_reason=None
# Result: ORDER
# Response from Maitai (Test Case ID: None): id='2e7f6cc3-e261-4cf6-9b6a-53604ad7b141' object='chat.completion' created=1767349568 model='claude-3-7-sonnet-latest' system_fingerprint=None choices=[ChatCompletionChoice(index=0, message=MaitaiMessage(role='assistant', content='CONTACT', function_call=None, tool_calls=None, refusal=None, response_format={'type': 'text'}), logprobs=None, finish_reason='stop', is_correction=False)] usage=ChatCompletionUsage(prompt_tokens=209, completion_tokens=5, total_tokens=214, cost=0.0, model='claude-3-7-sonnet-latest', completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)) request_id='2e7f6cc3-e261-4cf6-9b6a-53604ad7b141' evaluate_response=None correction_applied=False first_token_time=0.0 response_time=675.0 chat_completion_request=None service_tier=None input_safety_score=0.0 fallback_reason=None
# Result: CONTACT

# %%
with open("output.json", "w") as f:
    json.dump(response.dict(), f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 with open("output.json", "w") as f:
# ----> 2     json.dump(response.dict(), f, indent=2)
#
# NameError: name 'response' is not defined
